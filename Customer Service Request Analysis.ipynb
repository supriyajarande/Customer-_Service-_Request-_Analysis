# %%
#Import libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read the data
df = pd.read_csv("311_Service_Requests_from_2010_to_Present.csv")
# Out:
# C:\Users\Sachin\AppData\Local\Temp\ipykernel_6744\3360345142.py:2: DtypeWarning: Columns (48,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("311_Service_Requests_from_2010_to_Present.csv")

# %%
df.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    32310363  12/31/2015 11:59:45 PM  01/01/2016 12:55:15 AM   NYPD
# 1    32309934  12/31/2015 11:59:44 PM  01/01/2016 01:26:57 AM   NYPD
# 2    32309159  12/31/2015 11:59:29 PM  01/01/2016 04:51:03 AM   NYPD
# 3    32305098  12/31/2015 11:57:46 PM  01/01/2016 07:43:13 AM   NYPD
# 4    32306529  12/31/2015 11:56:58 PM  01/01/2016 03:24:42 AM   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# ...

# %% [markdown]
# # 1. Understand the dataset

# %%
# 1(i)Identify the shape of the dataset
df.shape
# Out:
# (364558, 53)

# %%
# df[::30] To access row

# %%
#print all the columns
df.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Description', 'Resolution Action Updated Date',
#        'Community Board', 'Borough', 'X Coordinate (State Plane)',
#        'Y Coordinate (State Plane)', 'Park Facility Name', 'Park Borough',
#        'School Name', 'School Number', 'School Region', 'School Code',
#        'School Phone Number', 'School Address', 'School City', 'School State',
#        'School Zip', 'School Not Found', 'School or Citywide Complaint',
#        'Vehicle Type', 'Taxi Company Borough', 'Taxi Pick Up Location',
#        'Bridge Highway Name', 'Bridge Highway Direction', 'Road Ramp',
# ...

# %%
# verify whether the null value present in the dataset, if present then it will give boolean value True else false 
df.isnull()
# Out:
#         Unique Key  Created Date  Closed Date  Agency  Agency Name  \
# 0            False         False        False   False        False
# 1            False         False        False   False        False
# 2            False         False        False   False        False
# 3            False         False        False   False        False
# 4            False         False        False   False        False
# ...            ...           ...          ...     ...          ...
# 364553       False         False        False   False        False
# 364554       False         False        False   False        False
# 364555       False         False        False   False        False
# 364556       False         False        False   False        False
# 364557       False         False        False   False        False
#
#         Complaint Type  Descriptor  Location Type  Incident Zip  \
# 0                False       False          False         False
# ...

# %%
# 1(ii)Identify variables with null values
df.isnull().sum()
# Out:
# Unique Key                             0
# Created Date                           0
# Closed Date                         2381
# Agency                                 0
# Agency Name                            0
# Complaint Type                         0
# Descriptor                          6501
# Location Type                        133
# Incident Zip                        2998
# Incident Address                   51699
# Street Name                        51699
# Cross Street 1                     57188
# Cross Street 2                     57805
# Intersection Street 1             313438
# Intersection Street 2             314046
# Address Type                        3252
# City                                2997
# Landmark                          364183
# Facility Type                       2389
# Status                                 0
# Due Date                               3
# Resolution Description                 0
# Resolution Action Updated Date      2402
# ...

# %%
#Sum of all null value in dataset
df.isnull().sum().sum()
# Out:
# 5262284

# %% [markdown]
# # 2 Perform basic data exploratory analysis

# %%
# 2(i)Utilize missing value treatment

#Drop the row which has all null value
df.dropna(how='all')
# Out:
#         Unique Key            Created Date             Closed Date Agency  \
# 0         32310363  12/31/2015 11:59:45 PM  01/01/2016 12:55:15 AM   NYPD
# 1         32309934  12/31/2015 11:59:44 PM  01/01/2016 01:26:57 AM   NYPD
# 2         32309159  12/31/2015 11:59:29 PM  01/01/2016 04:51:03 AM   NYPD
# 3         32305098  12/31/2015 11:57:46 PM  01/01/2016 07:43:13 AM   NYPD
# 4         32306529  12/31/2015 11:56:58 PM  01/01/2016 03:24:42 AM   NYPD
# ...            ...                     ...                     ...    ...
# 364553    29609918  01/01/2015 12:04:44 AM  01/01/2015 10:22:31 AM   NYPD
# 364554    29608392  01/01/2015 12:04:28 AM  01/01/2015 02:25:02 AM   NYPD
# 364555    29607589  01/01/2015 12:01:30 AM  01/01/2015 12:20:33 AM   NYPD
# 364556    29610889  01/01/2015 12:01:29 AM  01/01/2015 02:42:22 AM   NYPD
# 364557    29611816  01/01/2015 12:00:50 AM  01/01/2015 02:47:50 AM   NYPD
#
#                             Agency Name           Complaint Type  \
# ...

# %%
# Drop the cell which has null value
df.dropna(subset=['Created Date','Closed Date'])
# Out:
#         Unique Key            Created Date             Closed Date Agency  \
# 0         32310363  12/31/2015 11:59:45 PM  01/01/2016 12:55:15 AM   NYPD
# 1         32309934  12/31/2015 11:59:44 PM  01/01/2016 01:26:57 AM   NYPD
# 2         32309159  12/31/2015 11:59:29 PM  01/01/2016 04:51:03 AM   NYPD
# 3         32305098  12/31/2015 11:57:46 PM  01/01/2016 07:43:13 AM   NYPD
# 4         32306529  12/31/2015 11:56:58 PM  01/01/2016 03:24:42 AM   NYPD
# ...            ...                     ...                     ...    ...
# 364553    29609918  01/01/2015 12:04:44 AM  01/01/2015 10:22:31 AM   NYPD
# 364554    29608392  01/01/2015 12:04:28 AM  01/01/2015 02:25:02 AM   NYPD
# 364555    29607589  01/01/2015 12:01:30 AM  01/01/2015 12:20:33 AM   NYPD
# 364556    29610889  01/01/2015 12:01:29 AM  01/01/2015 02:42:22 AM   NYPD
# 364557    29611816  01/01/2015 12:00:50 AM  01/01/2015 02:47:50 AM   NYPD
#
#                             Agency Name           Complaint Type  \
# ...

# %%
#drop the column which has all null value
df1 = df.dropna(how='all', axis=1)
print(df1)
# Out:
#         Unique Key            Created Date             Closed Date Agency  \
# 0         32310363  12/31/2015 11:59:45 PM  01/01/2016 12:55:15 AM   NYPD
# 1         32309934  12/31/2015 11:59:44 PM  01/01/2016 01:26:57 AM   NYPD
# 2         32309159  12/31/2015 11:59:29 PM  01/01/2016 04:51:03 AM   NYPD
# 3         32305098  12/31/2015 11:57:46 PM  01/01/2016 07:43:13 AM   NYPD
# 4         32306529  12/31/2015 11:56:58 PM  01/01/2016 03:24:42 AM   NYPD
# ...            ...                     ...                     ...    ...
# 364553    29609918  01/01/2015 12:04:44 AM  01/01/2015 10:22:31 AM   NYPD
# 364554    29608392  01/01/2015 12:04:28 AM  01/01/2015 02:25:02 AM   NYPD
# 364555    29607589  01/01/2015 12:01:30 AM  01/01/2015 12:20:33 AM   NYPD
# 364556    29610889  01/01/2015 12:01:29 AM  01/01/2015 02:42:22 AM   NYPD
# 364557    29611816  01/01/2015 12:00:50 AM  01/01/2015 02:47:50 AM   NYPD
#
#                             Agency Name           Complaint Type  \
# ...

# %%
# Handle missing value by filling with 0
df2=df1.fillna(value = 0)
df2
# Out:
#         Unique Key            Created Date             Closed Date Agency  \
# 0         32310363  12/31/2015 11:59:45 PM  01/01/2016 12:55:15 AM   NYPD
# 1         32309934  12/31/2015 11:59:44 PM  01/01/2016 01:26:57 AM   NYPD
# 2         32309159  12/31/2015 11:59:29 PM  01/01/2016 04:51:03 AM   NYPD
# 3         32305098  12/31/2015 11:57:46 PM  01/01/2016 07:43:13 AM   NYPD
# 4         32306529  12/31/2015 11:56:58 PM  01/01/2016 03:24:42 AM   NYPD
# ...            ...                     ...                     ...    ...
# 364553    29609918  01/01/2015 12:04:44 AM  01/01/2015 10:22:31 AM   NYPD
# 364554    29608392  01/01/2015 12:04:28 AM  01/01/2015 02:25:02 AM   NYPD
# 364555    29607589  01/01/2015 12:01:30 AM  01/01/2015 12:20:33 AM   NYPD
# 364556    29610889  01/01/2015 12:01:29 AM  01/01/2015 02:42:22 AM   NYPD
# 364557    29611816  01/01/2015 12:00:50 AM  01/01/2015 02:47:50 AM   NYPD
#
#                             Agency Name           Complaint Type  \
# ...

# %%
# to check whether null value still in dataset
df2.isnull().sum()
# Out:
# Unique Key                        0
# Created Date                      0
# Closed Date                       0
# Agency                            0
# Agency Name                       0
# Complaint Type                    0
# Descriptor                        0
# Location Type                     0
# Incident Zip                      0
# Incident Address                  0
# Street Name                       0
# Cross Street 1                    0
# Cross Street 2                    0
# Intersection Street 1             0
# Intersection Street 2             0
# Address Type                      0
# City                              0
# Landmark                          0
# Facility Type                     0
# Status                            0
# Due Date                          0
# Resolution Description            0
# Resolution Action Updated Date    0
# Community Board                   0
# Borough                           0
# X Coordinate (State Plane)        0
# ...

# %%
df2["Created Date"] = pd.to_datetime(df2["Created Date"])
df2["Closed Date"] = pd.to_datetime(df2["Closed Date"])

# %%
df2.dtypes

# %%
df2["Created Date"].value_counts()[:3]
# Out:
# Created Date
# 2015-02-11 22:56:36    3
# 2015-08-15 22:49:03    3
# 2015-06-03 22:16:23    3
# Name: count, dtype: int64

# %%
# 2(ii) Analyze the date column and remove the entries if it has an incorrect timeline
df3 = pd.to_datetime(df2['Created Date'],format="%m/%d/%Y %H:%M:%S")
df4 = pd.to_datetime(df2['Closed Date'],format="%m/%d/%Y %H:%M:%S")
df4
# Out:
# 0        2016-01-01 00:55:15
# 1        2016-01-01 01:26:57
# 2        2016-01-01 04:51:03
# 3        2016-01-01 07:43:13
# 4        2016-01-01 03:24:42
#                  ...
# 364553   2015-01-01 10:22:31
# 364554   2015-01-01 02:25:02
# 364555   2015-01-01 00:20:33
# 364556   2015-01-01 02:42:22
# 364557   2015-01-01 02:47:50
# Name: Closed Date, Length: 364558, dtype: datetime64[ns]

# %%
#2(iii)Draw a frequency plot for city-wise complaints
from matplotlib.pyplot import figure 
figure(figsize=(10,3 ), dpi=80) 

#fd1= df.groupby(["City"]).size().sort_values(ascending=False)[1:]
fd1 = df2["City"].value_counts()[0:10]
print(fd1.head())
fd1.plot();
# Out:
# City
# BROOKLYN         118862
# NEW YORK          77312
# BRONX             49171
# STATEN ISLAND     15340
# JAMAICA            8932
# Name: count, dtype: int64

# %%
#2(iii)Draw a frequency plot for city-wise complaints
City_Name = df2.groupby(["City"]).size().sort_values(ascending=False)[0:]
print(City_Name.head())
City_Name.plot();
# Out:
# City
# BROOKLYN         118862
# NEW YORK          77312
# BRONX             49171
# STATEN ISLAND     15340
# JAMAICA            8932
# dtype: int64

# %%
df_Brooklyn = df[df['Borough']=='BROOKLYN']

# %%
(df_Brooklyn['Complaint Type'].value_counts())
# Out:
# Complaint Type
# Blocked Driveway             36447
# Illegal Parking              33533
# Noise - Street/Sidewalk      13983
# Noise - Commercial           13860
# Derelict Vehicle              6260
# Noise - Vehicle               5966
# Animal Abuse                  3191
# Noise - Park                  1575
# Traffic                       1260
# Homeless Encampment            948
# Vending                        575
# Noise - House of Worship       389
# Drinking                       291
# Urinating in Public            155
# Bike/Roller/Skate Chronic      124
# Disorderly Youth                79
# Illegal Fireworks               61
# Graffiti                        60
# Posting Advertisement           58
# Panhandling                     49
# Name: count, dtype: int64

# %%
#2(iv)Hexbin plot of concentration of complaints across Brooklyn 
df_Brooklyn.plot(
    kind='hexbin', x='Longitude', y='Latitude', gridsize=40,title = 'concentration of complaints across Brooklyn\n',
    colormap='jet', mincnt=1, figsize=(10,6)).axis('equal')
# Out:
# (-74.05061403048781, -73.8464793432815, 40.563150823850876, 40.74729501421672)

# %%
#2(iv)Scatter plot of concentration of complaints across Brooklyn 
df_Brooklyn.plot.scatter( x='Longitude', y='Latitude', title = 'concentration ofcomplaints across Brooklyn\n',
    figsize=(10,6)).axis('equal')
# Out:
# (-74.05061403028367, -73.84647934348564, 40.563150823850876, 40.74729501421672)

# %% [markdown]
# # 3  Find major types of complaints

# %%
# 3(ii)Find top 10 complaints
Complaint = df.groupby(["Complaint Type"]).size().sort_values(ascending=False)[1:]
Complaint
# Out:
# Complaint Type
# Illegal Parking              92679
# Noise - Street/Sidewalk      51692
# Noise - Commercial           44109
# Derelict Vehicle             21661
# Noise - Vehicle              19352
# Animal Abuse                 10541
# Traffic                       5198
# Homeless Encampment           4879
# Vending                       4192
# Noise - Park                  4109
# Drinking                      1409
# Noise - House of Worship      1070
# Posting Advertisement          681
# Urinating in Public            641
# Bike/Roller/Skate Chronic      478
# Panhandling                    327
# Disorderly Youth               315
# Illegal Fireworks              172
# Graffiti                       157
# Agency Issues                    8
# Squeegee                         4
# Ferry Complaint                  2
# Animal in a Park                 1
# dtype: int64

# %%
#3(i)Plot a bar graph of count vs. complaint types
Complaint.plot(kind="bar", figsize=(10,10), stacked=True)
# Out:
# <Axes: xlabel='Complaint Type'>

# %%
# 3(iii)Display the types of complaints in each city in a separate dataset
# Display the complaints in Brooklyn borough 
df_Brooklyn = df[df['Borough']=='BROOKLYN']

# %%
(df_Brooklyn['Complaint Type'].value_counts())
# Out:
# Complaint Type
# Blocked Driveway             36447
# Illegal Parking              33533
# Noise - Street/Sidewalk      13983
# Noise - Commercial           13860
# Derelict Vehicle              6260
# Noise - Vehicle               5966
# Animal Abuse                  3191
# Noise - Park                  1575
# Traffic                       1260
# Homeless Encampment            948
# Vending                        575
# Noise - House of Worship       389
# Drinking                       291
# Urinating in Public            155
# Bike/Roller/Skate Chronic      124
# Disorderly Youth                79
# Illegal Fireworks               61
# Graffiti                        60
# Posting Advertisement           58
# Panhandling                     49
# Name: count, dtype: int64

# %%
#shape
df_Brooklyn.shape
# Out:
# (118864, 53)

# %%
# Display the Complaints in Bronx Borough

# %%
df_Bronx = df[df['Borough']=='BRONX']

# %%
(df_Bronx['Complaint Type'].value_counts())
# Out:
# Complaint Type
# Blocked Driveway             17063
# Illegal Parking               9888
# Noise - Street/Sidewalk       9144
# Noise - Vehicle               3556
# Noise - Commercial            2945
# Derelict Vehicle              2403
# Animal Abuse                  1971
# Noise - Park                   548
# Vending                        433
# Traffic                        429
# Homeless Encampment            274
# Drinking                       206
# Noise - House of Worship        90
# Disorderly Youth                66
# Urinating in Public             54
# Illegal Fireworks               24
# Bike/Roller/Skate Chronic       22
# Panhandling                     20
# Posting Advertisement           18
# Graffiti                        15
# Name: count, dtype: int64

# %%
# Display the complaints in Staten Island Borough

# %%
df_Statenisland = df[df['Borough']=='STATEN ISLAND']

# %%
(df_Statenisland['Complaint Type'].value_counts())
# Out:
# Complaint Type
# Illegal Parking              6223
# Blocked Driveway             2845
# Derelict Vehicle             2184
# Noise - Street/Sidewalk       889
# Animal Abuse                  786
# Noise - Commercial            785
# Posting Advertisement         517
# Noise - Vehicle               424
# Traffic                       227
# Drinking                      188
# Homeless Encampment            77
# Noise - Park                   67
# Disorderly Youth               25
# Vending                        25
# Urinating in Public            19
# Noise - House of Worship       18
# Panhandling                    13
# Illegal Fireworks              11
# Bike/Roller/Skate Chronic      10
# Graffiti                        6
# Name: count, dtype: int64

# %% [markdown]
# # 4 Visualize the major types of complaints in each city

# %%
# 4(i)Visualize complaint in Brooklyn borough
(df_Brooklyn['Complaint Type'].value_counts()).head(25).plot(kind='bar',
                                                    figsize=(10,6),title = 'Complaints in Brooklyn')
# Out:
# <Axes: title={'center': 'Complaints in Brooklyn'}, xlabel='Complaint Type'>

# %%
#Visualize the Complaints in Staten Island Borough
(df_Bronx['Complaint Type'].value_counts()).head(25).plot(kind='bar',
                                                    figsize=(10,6),title = 'Complaints in Bronx')
# Out:
# <Axes: title={'center': 'Complaints in Bronx'}, xlabel='Complaint Type'>

# %%
#Visualise the Complaints in Staten Island Borough
(df_Statenisland['Complaint Type'].value_counts()).head(25).plot(kind='bar',
                                                    figsize=(10,6),title = 'Complaints in Statenisland')
# Out:
# <Axes: title={'center': 'Complaints in Statenisland'}, xlabel='Complaint Type'>
